# %% [markdown]
# <a href="https://colab.research.google.com/github/nadhifazlfa/tugas-praktikum_strukdat_stack/blob/main/Untitled4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
   # Tugas
class TowerOfHanoi:
    def __init__(self, num_disks, max_steps):
       self.towers = {
            'A': list(range(num_disks, 0, -1)),
            'B': [],
            'C': []
       }
       self.num_disks = num_disks
       self.max_steps = max_steps
       self.steps_taken = 0

    def move_disk(self, from_tower, to_tower):
        if self.steps_taken >= self.max_steps:
            print("Batas langkah maksimal tercapai!")
            return

        if not self.towers[from_tower]:
            print(f"Tidak ada cakram di tiang {from_tower} untuk dipindahkan!")
            return

        if self.towers[to_tower] and self.towers[to_tower][-1] < self.towers[from_tower][-1]:
            print("Tidak bisa menaruh cakram besar di atas cakram kecil!")
            return

        disk = self.towers[from_tower].pop()
        self.towers[to_tower].append(disk)
        self.steps_taken += 1
        print(f"Memindahkan cakram {disk} dari {from_tower} ke {to_tower}")

    def display_towers(self):
        print("\nKondisi Tiang:")
        for key, value in self.towers.items():
            print(f"{key}: {value}")
        print(f"Langkah: {self.steps_taken}/{self.max_steps}")

    def is_solved(self):
        return len(self.towers['B']) == self.num_disks

num_disks = 3
max_steps = 12

game = TowerOfHanoi(num_disks, max_steps)


while not game.is_solved():
    game.display_towers()
    print("\n🔹 Pilih langkah: ")
    from_tower = input("Pindahkan dari tiang (A/B/C): ").upper()
    to_tower = input("Ke tiang (A/B/C): ").upper()

    if from_tower in "ABC" and to_tower in "ABC" and from_tower != to_tower:
        game.move_disk(from_tower, to_tower)
    else:
        print("Masukkan tidak valid! Harap pilih antara A, B, atau C.")

    if game.steps_taken >= max_steps:
        print("\nBatas langkah tercapai! Game Over.")
        break

if game.is_solved():
    print("\nSelamat! Anda menyelesaikan Tower of Hanoi!")
# Out:
# Kondisi Tiang:
# A: [3, 2, 1]
# B: []
# C: []
# Langkah: 0/12
#
# 🔹 Pilih langkah:
# Pindahkan dari tiang (A/B/C): A
# Ke tiang (A/B/C): C
# Memindahkan cakram 1 dari A ke C
#
# Kondisi Tiang:
# A: [3, 2]
# B: []
# C: [1]
# Langkah: 1/12
#
# 🔹 Pilih langkah:
# Pindahkan dari tiang (A/B/C): A
# Ke tiang (A/B/C): B
# Memindahkan cakram 2 dari A ke B
#
# Kondisi Tiang:
# A: [3]
# B: [2]
# C: [1]
# Langkah: 2/12
#
# 🔹 Pilih langkah:
# Pindahkan dari tiang (A/B/C): C
# Ke tiang (A/B/C): B
# Memindahkan cakram 1 dari C ke B
#
# Kondisi Tiang:
# A: [3]
# B: [2, 1]
# C: []
# Langkah: 3/12
#
# 🔹 Pilih langkah:
# Pindahkan dari tiang (A/B/C): A
# Ke tiang (A/B/C): C
# Memindahkan cakram 3 dari A ke C
#
# Kondisi Tiang:
# A: []
# B: [2, 1]
# C: [3]
# Langkah: 4/12
#
# 🔹 Pilih langkah:
# Pindahkan dari tiang (A/B/C): B
# Ke tiang (A/B/C): A
# Memindahkan cakram 1 dari B ke A
#
# Kondisi Tiang:
# A: [1]
# B: [2]
# C: [3]
# Langkah: 5/12
#
# 🔹 Pilih langkah:
# Pindahkan dari tiang (A/B/C): B
# Ke tiang (A/B/C): C
# Memindahkan cakram 2 dari B ke C
#
# Kondisi Tiang:
# A: [1]
# B: []
# C: [3, 2]
# Langkah: 6/12
#
# 🔹 Pilih langkah:
# Pindahkan dari tiang (A/B/C): A
# Ke tiang (A/B/C): C
# Memindahkan cakram 1 dari A ke C
#
# Kondisi Tiang:
# A: []
# B: []
# C: [3, 2, 1]
# Langkah: 7/12
#
# 🔹 Pilih langkah:
# Pindahkan dari tiang (A/B/C): A
# Ke tiang (A/B/C): C
# Tidak ada cakram di tiang A untuk dipindahkan!
#
# Kondisi Tiang:
# A: []
# B: []
# C: [3, 2, 1]
# Langkah: 7/12
#
# 🔹 Pilih langkah:
# Pindahkan dari tiang (A/B/C): C
# Ke tiang (A/B/C): A
# Memindahkan cakram 1 dari C ke A
#
# Kondisi Tiang:
# A: [1]
# B: []
# C: [3, 2]
# Langkah: 8/12
#
# 🔹 Pilih langkah:
